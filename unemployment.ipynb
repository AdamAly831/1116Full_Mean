# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamAly831/1116Full_Mean/blob/master/unemployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from vega_datasets import data
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
upempl_data=data.unemployment_across_industries()

# %%
upempl_data.head()
# Out:
#    count                date  month  rate      series  year
# 0    430 2000-01-01 08:00:00      1   2.1  Government  2000
# 1    409 2000-02-01 08:00:00      2   2.0  Government  2000
# 2    311 2000-03-01 08:00:00      3   1.5  Government  2000
# 3    269 2000-04-01 08:00:00      4   1.3  Government  2000
# 4    370 2000-05-01 07:00:00      5   1.9  Government  2000

# %%
upempl_data.series.unique()
# Out:
# array(['Government', 'Mining and Extraction', 'Construction',
#        'Manufacturing', 'Wholesale and Retail Trade',
#        'Transportation and Utilities', 'Information', 'Finance',
#        'Business services', 'Education and Health',
#        'Leisure and hospitality', 'Other', 'Agriculture', 'Self-employed'],
#       dtype=object)

# %%
import pandas as pd
import seaborn as sns

# %%
plt.figure(figsize=(15, 10))
sns.scatterplot(x='count', y='rate', hue='rate',  data = upempl_data)
plt.show()

# %%
sns.lineplot(x='year', y='date', hue='count', data=upempl_data)
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-63-8b506090b0d0> in <module>()
# ----> 1 sns.lineplot(x='year', y='date', hue='count', data=upempl_data)
#       2
#       3 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# /usr/local/lib/python3.6/dist-packages/seaborn/relational.py in plot(self, ax, kws)
#     773                     err = "estimator must be None when specifying units"
#     774                     raise ValueError(err)
# --> 775                 x, y, y_ci = self.aggregate(y, x, units)
# ...
